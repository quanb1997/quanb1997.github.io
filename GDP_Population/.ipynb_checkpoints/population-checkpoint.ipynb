# %%
import pandas as pd

# %%
Population_Data = {'Population': []} #Polulation is country name

# %%
Population_Data =  pd.DataFrame(Population_Data)

# %%
# cd ../myPopulation
# Out:
# /Users/mac/Desktop/mind-gapper-js-master/myPopulation

# %%
Countries = {
    'Australia':'AUS',
    'Austria':'AUT',
    'Belgium':'BEL',
    'Bulgaria':'BGR',
    'Brazil':'BRA',
    'Canada': 'CAN',
    'Switzerland':'CHE',
    'China':'CHN',
    'Cyprus':'CYP',
    'Czech Republic':'CZE',
    'Germany':'DEU',
    'Denmark':'DNK',
    'Spain':'ESP',
    'Burkina Faso':'EST',
    
    'Finland':'FIN',
    'France':'FRA',
    'United Kingdom':'GBR',
    'Greece' : 'GRC',
    'Croatia':'HRV',  #HVR
    'Hungary':'HUN',
    'Indonesia':'IDN',
    'India':'IND',
    'Ireland': 'IRL',
    'Italy':'ITA',
    'Japan':'JPN',

    'Korea, Rep.':'KOR',
    'Lithuania': 'LTU',
    'Luxembourg':'LUX',
    'Latvia':'LVA',
    'Mexico': 'MEX',
    'Malta':'MLT',
    'Netherlands':'NLD',
    'Norway':'NOR',
    'Poland':'POL',
    'Portugal' :'PRT',
    'Romania':'ROU',
    'Russian Federation':'RUS',
    'Slovak Republic':'SVK', #'SYK'
    'Slovenia':'SVN', #'SYN'
    'Sweden':'SWE',
    'Turkey':'TUR',
    'Taiwan':'TWN',
    'United States':'USA',
    'Rest Of World':'ROW'  
}

# %%
#pwd
# Out:
# '/Users/mac/Desktop/mind-gapper-js-master/myPopulation'

# %%
for year in range(2000, 2015, 1):

    #df = pd.read_csv('population_' + str(year) + '.csv')
    df = pd.read_csv('GdpPop' + str(year) + '.csv')

    country_name = list(x for x in df['Country'])

    Population_Data['Population'] = country_name

    population = list(x for x in df['Population'])


    Population_Data[str(year)] = population

# %%
Population_Data
# Out:
#    Population        2000        2001        2002        2003        2004  \
# 0         AUS    19153.00    19413.00    19651.40    19895.40    20127.40
# 1         AUT     8011.57     8042.29     8081.96     8121.42     8171.97
# 2         BEL    10251.25    10286.57    10332.78    10376.13    10421.14
# 3         BRA   175287.59   177750.67   180151.02   182482.15   184738.46
# 4         BGR     8170.17     8009.14     7837.16     7775.33     7716.86
# 5         EST    11607.94    11944.59    12293.10    12654.62    13030.57
# 6         CAN    30769.70    31081.90    31362.00    31676.00    31995.00
# 7         CHN  1262645.00  1271850.00  1280400.00  1288400.00  1296075.00
# 8         HRV     4426.00     4440.00     4440.00     4440.00     4439.00
# 9         CYP      943.29      960.28      976.97      993.56     1010.41
# 10        CZE    10255.06    10216.60    10196.92    10194.00    10197.10
# 11        DNK     5339.62     5358.78     5375.93     5390.57     5404.52
# ...

# %%
Population_Data.to_csv (path_or_buf= '../project_data/indicator_population.csv', index = None, header=True)
